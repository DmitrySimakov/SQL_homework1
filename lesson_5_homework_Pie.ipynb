# %%
# !pip install psycopg2
# !pip install plotly
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11434 sha256=16cec2355a3f42b6dc9eb6ac7523a39f0a2a7d2854d67ba9e7823a1628cd1b46
#   Stored in directory: c:\users\sber\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# ...

# %%
import psycopg2
import pandas as pd
#Библиотека ждя визуализации
from IPython.display import HTML
import plotly.express as px 
import matplotlib.pyplot as plt


#!введите свои реквизиты!
DB_HOST = '52.157.159.24'
DB_USER = 'student11'
DB_USER_PASSWORD = 'student11_password'
DB_NAME = 'sql_ex_for_student11'

conn = psycopg2.connect(host=DB_HOST, user=DB_USER, password=DB_USER_PASSWORD, dbname=DB_NAME)

# %%
request1 = """

select *
from distribution_by_type
where maker = 'A'

"""
df1 = pd.read_sql_query(request1, conn)

# %%
request2 = """

select *
from distribution_by_type
where maker = 'B'

"""
df2 = pd.read_sql_query(request2, conn)

# %%
request3 = """

select *
from distribution_by_type
where maker = 'C'

"""
df3 = pd.read_sql_query(request3, conn)

# %%
vals = df1.ratio.to_list()
labels = df1.type.to_list()
fig, ax = plt.subplots()
ax.pie(vals, labels = labels, autopct='%1.1f%%')
ax.set_title('Процентное соотношение типов товаров у производителя А')
# Out:
# Text(0.5, 1.0, 'Процентное соотношение типов товаров у производителя А')

# %%
vals2 = df2.ratio.to_list()
labels2 = df2.type.to_list()
fig, ax = plt.subplots()
ax.pie(vals2, labels = labels2, autopct='%1.1f%%')
ax.set_title('Процентное соотношение типов товаров у производителя B')
# Out:
# Text(0.5, 1.0, 'Процентное соотношение типов товаров у производителя B')

# %%
vals3 = df3.ratio.to_list()
labels3 = df3.type.to_list()
fig, ax = plt.subplots()
ax.pie(vals3, labels = labels3, autopct='%1.1f%%')
ax.set_title('Процентное соотношение типов товаров у производителя C')
# Out:
# Text(0.5, 1.0, 'Процентное соотношение типов товаров у производителя C')
